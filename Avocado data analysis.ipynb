# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\HP\\Desktop\\DT\\dataset\\avocado.csv")

# %%
data.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# 5         5.0  22-11-2015          1.26      55979.78  1184.27   48067.99
# 6         6.0  15-11-2015          0.99      83453.76  1368.92   73672.72
# 7         7.0  08-11-2015          0.98     109428.33   703.75  101815.36
# 8         8.0  01-11-2015          1.02      99811.42  1022.15   87315.57
# 9         9.0  25-10-2015          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
data.shape
# Out:
# (16468, 14)

# %%
data.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Lets detect outlier
# We can detect outlier by below techniques:
# 1. Use standard deviation
# 2. Use quantile

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data[data['AveragePrice'].isnull()]
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 1517          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1518          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1519          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1520          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1521          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1522          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1523          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1524          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1525          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1526          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1527          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1528          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1529          NaN  NaN           NaN           NaN   NaN   NaN   NaN
# ...

# %%
df = data.dropna()

# %%
df.shape
# Out:
# (1517, 14)

# %%
df.tail(10)
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 1507         5.0  20-11-2016          1.57     135608.11  44044.69  28907.47
# 1508         6.0  13-11-2016          1.64     144089.12  49399.39  26597.39
# 1509         7.0  06-11-2016          1.57     142095.92  36840.74  27501.34
# 1510         8.0  30-10-2016          1.58     142955.49  39376.44  29382.30
# 1511         9.0  23-10-2016          1.52     167741.27  54981.90  39749.81
# 1512        10.0  16-10-2016          1.39     190846.01  57529.11  56366.66
# 1513        11.0  09-10-2016          1.51     178235.75  43325.87  52189.61
# 1514        12.0  02-10-2016          1.48     178410.82  46364.75  52893.38
# 1515        13.0  25-09-2016          1.47     189131.52  54110.79  53593.58
# 1516        14.0  18-09-2016          1.43     182978.30  43116.41  54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
sns.set_style("white")

plt.figure(figsize=(12,12))
sns.distplot(df.AveragePrice)
plt.title("Distribution of Average Price",fontsize=14)
# Out:
# C:\Users\HP\Anacondanew\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Distribution of Average Price')

# %% [markdown]
# This graph seems right skewed.

# %%
sm.qqplot(df.AveragePrice,line="s")

# %% [markdown]
# Use property of mean and standard deviation

# %%
mean = df.AveragePrice.mean()
std = df.AveragePrice.std()
lower, upper = mean-std*2,mean+std*2 # Use 2*std and it will exclude data that is not included in 95% of data
print("Lower bound : {} Upper bound : {}".format(lower,upper))
# Out:
# Lower bound : 0.6972076473594796 Upper bound : 1.4527725767670856

# %%
outliers = [x for x in df.AveragePrice if x < lower or x > upper]
outliers
# Out:
# [0.67,
#  0.67,
#  0.68,
#  0.62,
#  0.49,
#  0.53,
#  0.66,
#  0.56,
#  0.62,
#  0.6,
#  0.65,
#  0.58,
#  0.66,
#  0.56,
#  0.54,
#  0.53,
#  0.52,
#  0.56,
#  0.58,
#  0.67,
#  0.67,
#  0.6,
#  0.53,
#  0.51,
#  0.66,
#  0.57,
#  0.57,
#  0.6,
#  0.63,
#  0.6,
#  0.64,
#  0.56,
#  0.61,
#  0.67,
#  0.61,
#  0.65,
#  0.67,
#  0.69,
#  0.68,
#  1.52,
#  1.53,
#  1.49,
#  1.48,
#  1.52,
#  1.56,
#  1.62,
#  1.63,
#  1.46,
#  1.51,
#  1.62,
#  0.65,
#  0.58,
#  0.61,
#  0.63,
#  0.65,
#  0.67,
#  1.56,
#  1.62,
#  1.48,
#  1.61,
#  1.52,
#  1.56,
#  1.47,
#  1.66,
#  1.57,
#  1.63,
#  1.6,
#  1.5,
#  1.48,
#  1.68,
#  1.68,
#  1.54,
#  1.57,
#  1.64,
#  1.57,
#  1.58,
#  1.52,
#  1.51,
#  1.48,
#  1.47]

# %%
Data Normalization

# %%
log_data = np.log(df.AveragePrice+1)

sns.set_style("white")

plt.figure(figsize=(12,12))
sns.distplot(log_data)
plt.title("Distribution of Average Price",fontsize=14)
# Out:
# C:\Users\HP\Anacondanew\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Distribution of Average Price')

# %%
fig,ax = plt.subplots(1,2,figsize=(15,7))
sm.qqplot(df.AveragePrice,line="s",ax=ax[0])
ax[0].set_title("Before logarithmic")
sm.qqplot(log_data,line="s",ax=ax[1])
ax[1].set_title("After logarithmic")
# Out:
# Text(0.5,1,'After logarithmic')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
# Unnamed: 0      1517 non-null float64
# Date            1517 non-null object
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null object
# year            1517 non-null float64
# region          1517 non-null object
# dtypes: float64(11), object(3)
# memory usage: 177.8+ KB

# %% [markdown]
# Types of Avocados:
# In this section we will analyze the different types of avocados that we have in this dataset. Basically, we have two types of avocados:

# %%
df.groupby(['type']).sum().plot(kind='pie', y='Total Volume')

# %% [markdown]
# We have only one type of avocados across the region.

# %%
fig,ax = plt.subplots(figsize=(15,6))
df.groupby(['Date','type']).sum()['Total Volume'].unstack().plot(ax=ax)
plt.title('Total amount of avocado  over time')
# Out:
# Text(0.5,1,'Total amount of avocado  over time')

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
plt.figure(figsize =(11,6))
plt.title('Avocado price in each country')
plt.xticks(rotation ='vertical')
sns.boxplot(x = 'region', y = 'AveragePrice', data = df, width = 1, whis= 2)

# %% [markdown]
# As per the analysis above,I found that San Francisco is the most expensive city to sell avocados in general, Houston is the cheapest area to sell.We will isolate the data according to the type of avocado and then take each type to find its prices according to the region and year. To clarify more, let's work

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
#seperating the prices to be predicted
y = df.AveragePrice
df.drop(['AveragePrice'], axis=1, inplace=True)

# %%
y
# Out:
# 0       1.33
# 1       1.35
# 2       0.93
# 3       1.08
# 4       1.28
# 5       1.26
# 6       0.99
# 7       0.98
# 8       1.02
# 9       1.07
# 10      1.12
# 11      1.28
# 12      1.31
# 13      0.99
# 14      1.33
# 15      1.28
# 16      1.11
# 17      1.07
# 18      1.34
# 19      1.33
# 20      1.12
# 21      1.45
# 22      1.11
# 23      1.26
# 24      1.05
# 25      1.35
# 26      1.37
# 27      1.27
# 28      1.32
# 29      1.07
#         ...
# 1487    0.94
# 1488    0.93
# 1489    0.93
# 1490    0.91
# 1491    0.96
# 1492    0.92
# 1493    0.89
# 1494    0.89
# 1495    0.82
# 1496    0.70
# 1497    0.88
# 1498    0.88
# 1499    0.90
# 1500    0.87
# 1501    0.73
# 1502    1.25
# 1503    1.24
# 1504    1.33
# 1505    1.34
# 1506    1.54
# 1507    1.57
# 1508    1.64
# 1509    1.57
# 1510    1.58
# 1511    1.52
# 1512    1.39
# 1513    1.51
# 1514    1.48
# 1515    1.47
# 1516    1.43
# Name: AveragePrice, Length: 1517, dtype: float64

# %%
#train-test split
#splitting the data into training and test datasets
from sklearn.model_selection import train_test_split

train1, test1, ytrain, ytest = train_test_split(df, y, train_size=0.7,test_size=0.3, random_state=0)

# %%
s = (train.dtypes == 'object')
object_cols = list(s[s].index)

n = (train.dtypes == ('float64','int64'))
numerical_cols = list(n[n].index)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
plt.violinplot(df['Total Volume'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1949c246da0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1949c246cc0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1949c250208>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1949c2504a8>}

# %%
train.shape
# Out:
# (1061, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
test.shape
# Out:
# (456, 13)

# %%
lm = LinearRegression()

# %%
train1
# Out:
#       Unnamed: 0        Date  Total Volume        4046        4225       4770  \
# 1366         2.0  11-12-2016     510800.58     3711.20   409645.98    5052.84
# 251          4.0  29-11-2015      97235.60    40352.94    22858.09   16653.11
# 411         42.0  08-03-2015    3134752.64   380674.20  1675102.29  253978.78
# 548          1.0  20-12-2015      56443.43     1703.96    30942.26    2554.61
# 249          2.0  13-12-2015     124617.07    69742.59    21750.83   12957.84
# 654         13.0  27-09-2015    1201066.41    15448.68   941112.78     983.60
# 1212         5.0  22-11-2015    4481990.34  1549012.12  1588339.47  118170.98
# 579         32.0  17-05-2015      73537.14     2114.98    48390.37    4737.13
# 1410         2.0  11-12-2016      89037.86      967.77    62963.23      54.34
# 426         43.0  01-03-2015     230913.14    28899.98   134019.55     614.07
# 1218        11.0  11-10-2015    5534450.99  1287965.79  2714363.53  178042.28
# ...

# %%
train1.shape
# Out:
# (319, 61)

# %%
train2 =pd.get_dummies(train1, columns=["region","type"], prefix=["rg", "typ"]).head(456)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-228-625fc654b268> in <module>()
# ----> 1 train2 =pd.get_dummies(train1, columns=["region","type"], prefix=["rg", "typ"]).head(456)
#
# ~\Anacondanew\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     830                 include=dtypes_to_encode)
#     831         else:
# --> 832             data_to_encode = data[columns]
#     833
#     834         # validate prefixes and separator to avoid silently dropping cols
#
# ~\Anacondanew\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
# ...

# %%
train2 =pd.get_dummies(train1, columns=["region","type"], prefix=["rg", "typ"]).head(456)

# %%
train2.head(10)
# Out:
#       Unnamed: 0        Date  Total Volume        4046        4225       4770  \
# 1366         2.0  11-12-2016     510800.58     3711.20   409645.98    5052.84
# 251          4.0  29-11-2015      97235.60    40352.94    22858.09   16653.11
# 411         42.0  08-03-2015    3134752.64   380674.20  1675102.29  253978.78
# 548          1.0  20-12-2015      56443.43     1703.96    30942.26    2554.61
# 249          2.0  13-12-2015     124617.07    69742.59    21750.83   12957.84
# 654         13.0  27-09-2015    1201066.41    15448.68   941112.78     983.60
# 1212         5.0  22-11-2015    4481990.34  1549012.12  1588339.47  118170.98
# 579         32.0  17-05-2015      73537.14     2114.98    48390.37    4737.13
# 1410         2.0  11-12-2016      89037.86      967.77    62963.23      54.34
# 426         43.0  01-03-2015     230913.14    28899.98   134019.55     614.07
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags        ...         \
# ...

# %%
train2.head(5)
# Out:
#       Unnamed: 0        Date  Total Volume       4046        4225       4770  \
# 1366         2.0  11-12-2016     510800.58    3711.20   409645.98    5052.84
# 251          4.0  29-11-2015      97235.60   40352.94    22858.09   16653.11
# 411         42.0  08-03-2015    3134752.64  380674.20  1675102.29  253978.78
# 548          1.0  20-12-2015      56443.43    1703.96    30942.26    2554.61
# 249          2.0  13-12-2015     124617.07   69742.59    21750.83   12957.84
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags        ...         \
# 1366    92390.56    90449.44     1634.18       306.94        ...
# 251     17371.46    12106.21     4115.58      1149.67        ...
# 411    824997.37   697812.88   114519.60     12664.89        ...
# 548     21242.60    11290.59     9360.13       591.88        ...
# 249     20165.81    14642.30     4307.42      1216.09        ...
#
#       rg_SouthCentral  rg_Southeast  rg_Spokane  rg_StLouis  rg_Syracuse  \
# ...

# %%
train2.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'year',
#        'rg_Albany', 'rg_Atlanta', 'rg_BaltimoreWashington', 'rg_Boise',
#        'rg_Boston', 'rg_BuffaloRochester', 'rg_California', 'rg_Charlotte',
#        'rg_Chicago', 'rg_Columbus', 'rg_DallasFtWorth', 'rg_Denver',
#        'rg_Detroit', 'rg_GrandRapids', 'rg_GreatLakes',
#        'rg_HarrisburgScranton', 'rg_HartfordSpringfield', 'rg_Houston',
#        'rg_Indianapolis', 'rg_Jacksonville', 'rg_LasVegas', 'rg_LosAngeles',
#        'rg_Louisville', 'rg_MiamiFtLauderdale', 'rg_Midsouth', 'rg_Nashville',
#        'rg_NewYork', 'rg_Northeast', 'rg_NorthernNewEngland', 'rg_Orlando',
#        'rg_Philadelphia', 'rg_PhoenixTucson', 'rg_Pittsburgh', 'rg_Plains',
#        'rg_Portland', 'rg_RaleighGreensboro', 'rg_RichmondNorfolk',
#        'rg_Roanoke', 'rg_SanDiego', 'rg_SanFrancisco', 'rg_Seattle',
# ...

# %%
train2.drop(['Date'], axis = 1)
# Out:
#       Unnamed: 0  Total Volume         4046         4225        4770  \
# 1366         2.0     510800.58      3711.20    409645.98     5052.84
# 251          4.0      97235.60     40352.94     22858.09    16653.11
# 411         42.0    3134752.64    380674.20   1675102.29   253978.78
# 548          1.0      56443.43      1703.96     30942.26     2554.61
# 249          2.0     124617.07     69742.59     21750.83    12957.84
# 654         13.0    1201066.41     15448.68    941112.78      983.60
# 1212         5.0    4481990.34   1549012.12   1588339.47   118170.98
# 579         32.0      73537.14      2114.98     48390.37     4737.13
# 1410         2.0      89037.86       967.77     62963.23       54.34
# 426         43.0     230913.14     28899.98    134019.55      614.07
# 1218        11.0    5534450.99   1287965.79   2714363.53   178042.28
# 558         11.0      74536.59      2060.03     44941.49     4873.81
# 1209         2.0    4899439.92   1798995.46   1596329.01   134101.62
# ...

# %%
train3 = train2.drop(['year'], axis = 1)

# %%
train3
# Out:
#       Unnamed: 0        Date  Total Volume         4046         4225  \
# 1366         2.0  11-12-2016     510800.58      3711.20    409645.98
# 251          4.0  29-11-2015      97235.60     40352.94     22858.09
# 411         42.0  08-03-2015    3134752.64    380674.20   1675102.29
# 548          1.0  20-12-2015      56443.43      1703.96     30942.26
# 249          2.0  13-12-2015     124617.07     69742.59     21750.83
# 654         13.0  27-09-2015    1201066.41     15448.68    941112.78
# 1212         5.0  22-11-2015    4481990.34   1549012.12   1588339.47
# 579         32.0  17-05-2015      73537.14      2114.98     48390.37
# 1410         2.0  11-12-2016      89037.86       967.77     62963.23
# 426         43.0  01-03-2015     230913.14     28899.98    134019.55
# 1218        11.0  11-10-2015    5534450.99   1287965.79   2714363.53
# 558         11.0  11-10-2015      74536.59      2060.03     44941.49
# 1209         2.0  13-12-2015    4899439.92   1798995.46   1596329.01
# ...

# %%
train4 = train3.drop(['Date'], axis = 1)

# %%
train4
# Out:
#       Unnamed: 0  Total Volume         4046         4225        4770  \
# 1366         2.0     510800.58      3711.20    409645.98     5052.84
# 251          4.0      97235.60     40352.94     22858.09    16653.11
# 411         42.0    3134752.64    380674.20   1675102.29   253978.78
# 548          1.0      56443.43      1703.96     30942.26     2554.61
# 249          2.0     124617.07     69742.59     21750.83    12957.84
# 654         13.0    1201066.41     15448.68    941112.78      983.60
# 1212         5.0    4481990.34   1549012.12   1588339.47   118170.98
# 579         32.0      73537.14      2114.98     48390.37     4737.13
# 1410         2.0      89037.86       967.77     62963.23       54.34
# 426         43.0     230913.14     28899.98    134019.55      614.07
# 1218        11.0    5534450.99   1287965.79   2714363.53   178042.28
# 558         11.0      74536.59      2060.03     44941.49     4873.81
# 1209         2.0    4899439.92   1798995.46   1596329.01   134101.62
# ...

# %%
test.shape
# Out:
# (456, 13)

# %%
lm.fit(train4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-208-18887fb5614b> in <module>()
# ----> 1 lm.fit(train4)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
test1 = pd.get_dummies(test, columns=["region", "type"], prefix=["rg", "typ"]).head(456)

# %%
test2 = test1.drop(['Date'], axis = 1)

# %%
test3 = test2.drop(['year'], axis = 1)

# %%
test3.head(5)
# Out:
#       Unnamed: 0  Total Volume        4046        4225       4770  Total Bags  \
# 1224        17.0    5138256.91  2163511.05  1986059.01  124657.84   864029.01
# 580         33.0      85446.43     2278.40    60221.59     606.53    22339.91
# 9            9.0      74338.76      842.40    64757.44     113.00     8625.92
# 686         41.0    3135991.73   111777.91  2082038.09    5531.34   936644.39
# 685         40.0    3520408.65   118765.00  2526519.62    5436.84   869687.19
#
#       Small Bags  Large Bags  XLarge Bags  rg_Albany        ...         \
# 1224   624782.63   239195.91        50.47          0        ...
# 580      9533.88    12740.14        65.89          0        ...
# 9        8061.47      564.45         0.00          1        ...
# 686    843930.39    92714.00         0.00          0        ...
# 685    782209.83    87477.36         0.00          0        ...
#
#       rg_SouthCentral  rg_Southeast  rg_Spokane  rg_StLouis  rg_Syracuse  \
# ...

# %%
lm.fit(train4,test3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.coef_
# Out:
# array([[ 1.00643039e-02,  4.50485222e-06, -1.53926498e-06, ...,
#          4.92155836e+00,  3.92640818e+00,  0.00000000e+00],
#        [ 7.05919421e+03, -2.66668822e+00,  2.30237289e+00, ...,
#         -8.51596448e+05,  1.88651146e+05,  0.00000000e+00],
#        [ 3.78090240e+03, -1.54178595e+00,  1.25436290e+00, ...,
#         -3.44454305e+05,  1.32054298e+05,  0.00000000e+00],
#        ...,
#        [-8.40982987e-04, -3.25353357e-08,  3.62798968e-08, ...,
#         -3.40612682e-02, -1.91275384e-02,  0.00000000e+00],
#        [-1.00877670e-03, -1.53682246e-08,  9.24169546e-09, ...,
#         -1.59961928e-02, -1.42259195e-03,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
ytrain.shape
# Out:
# (319,)

# %%
xtrain = ytrain.head(456)

# %%
xtrain.shape
# Out:
# (319,)

# %%
ytest.shape
# Out:
# (137,)

# %%
lm.intercept
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-220-e92a238e21cb> in <module>()
# ----> 1 lm.intercept
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept'

# %%
train4.head(5)
# Out:
#       Unnamed: 0  Total Volume       4046        4225       4770  Total Bags  \
# 1366         2.0     510800.58    3711.20   409645.98    5052.84    92390.56
# 251          4.0      97235.60   40352.94    22858.09   16653.11    17371.46
# 411         42.0    3134752.64  380674.20  1675102.29  253978.78   824997.37
# 548          1.0      56443.43    1703.96    30942.26    2554.61    21242.60
# 249          2.0     124617.07   69742.59    21750.83   12957.84    20165.81
#
#       Small Bags  Large Bags  XLarge Bags  rg_Albany        ...         \
# 1366    90449.44     1634.18       306.94          0        ...
# 251     12106.21     4115.58      1149.67          0        ...
# 411    697812.88   114519.60     12664.89          0        ...
# 548     11290.59     9360.13       591.88          0        ...
# 249     14642.30     4307.42      1216.09          0        ...
#
#       rg_SouthCentral  rg_Southeast  rg_Spokane  rg_StLouis  rg_Syracuse  \
# ...

# %%
train4.shape
# Out:
# (456, 61)

# %%
train4
# Out:
#       Unnamed: 0  Total Volume       4046        4225       4770  Total Bags  \
# 1366         2.0     510800.58    3711.20   409645.98    5052.84    92390.56
# 251          4.0      97235.60   40352.94    22858.09   16653.11    17371.46
# 411         42.0    3134752.64  380674.20  1675102.29  253978.78   824997.37
# 548          1.0      56443.43    1703.96    30942.26    2554.61    21242.60
# 249          2.0     124617.07   69742.59    21750.83   12957.84    20165.81
#
#       Small Bags  Large Bags  XLarge Bags  rg_Albany        ...         \
# 1366    90449.44     1634.18       306.94          0        ...
# 251     12106.21     4115.58      1149.67          0        ...
# 411    697812.88   114519.60     12664.89          0        ...
# 548     11290.59     9360.13       591.88          0        ...
# 249     14642.30     4307.42      1216.09          0        ...
#
#       rg_SouthCentral  rg_Southeast  rg_Spokane  rg_StLouis  rg_Syracuse  \
# ...

# %%
y1= y.head(1000)

# %%
from sklearn.model_selection import train_test_split

train6, test6, atrain, btest = train_test_split(train4, y1, train_size=0.7,test_size=0.3, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-224-e26f3e3a6b01> in <module>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 train6, test6, atrain, btest = train_test_split(train4, y1, train_size=0.7,test_size=0.3, random_state=0)
#
# ~\Anacondanew\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2029         test_size = 0.25
#    2030
# -> 2031     arrays = indexable(*arrays)
#    2032
#    2033     if shuffle is False:
#
# ~\Anacondanew\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# ~\Anacondanew\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
# ...

# %%
train6.shape
# Out:
# (319, 61)

# %%
test6.shape
# Out:
# (137, 61)

# %%
atrain.shape
# Out:
# (319,)

# %%
btest.shape
# Out:
# (137,)

# %%
lm.score(train6,atrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-62e0c1e9787a> in <module>()
# ----> 1 lm.score(train6,atrain)
#
# ~\Anacondanew\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     385         from .metrics import r2_score
#     386         return r2_score(y, self.predict(X), sample_weight=sample_weight,
# --> 387                         multioutput='variance_weighted')
#     388
#     389
#
# ~\Anacondanew\lib\site-packages\sklearn\metrics\regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     528     """
#     529     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 530         y_true, y_pred, multioutput)
#     531
#     532     if sample_weight is not None:
#
# ~\Anacondanew\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
# ...

# %%
lm.fit(train6,atrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.score(train6,atrain)
# Out:
# 0.15857228593364203

# %%
lm.intercept_
# Out:
# 1.071437209102661

# %%
pred = lm.predict(test6)
print("predicted price:",pred)
print("actual price",btest)
# Out:
# predicted price: [1.0927622  1.10115767 1.16520358 1.13953885 1.13893186 1.17969653
#  1.07420779 1.08361232 1.15222828 1.07853471 1.09450447 1.11425192
#  1.18084865 1.09638634 1.03786696 1.1334851  1.05688465 1.12433046
#  1.1901358  1.10244701 1.07268689 1.1232614  1.17362538 1.09893738
#  1.11031176 1.13028802 1.11822581 1.0668079  1.10178177 1.09798548
#  1.1402372  1.13078683 1.13682803 1.0892498  1.13351244 1.07110591
#  1.06558718 1.14667117 1.05002917 1.11560483 1.03510879 1.03480722
#  1.08852169 1.1785799  1.06242246 1.08342972 1.07119582 1.07131877
#  1.05214239 1.05944529 1.14254929 1.0810318  1.10195222 1.08131163
#  1.08436927 1.0962177  1.11950828 1.18200084 1.12563468 1.09860884
#  1.06262393 1.16411292 1.03515302 1.11312509 1.06535039 1.05868352
#  1.05234592 1.08731454 1.13710497 1.07585864 1.05977146 1.17330965
#  1.11609136 1.00288634 1.05437998 1.08686159 1.16762204 1.08893976
#  1.13358785 1.10914203 1.14527057 1.16576954 1.15116204 1.03504459
# ...
